# %%
import json
import pandas as pd
from datetime import date


def read_log(log_path):
    """
    Opens the log file and transforms json to pandas dataframe
    and persisting data in a csv
    
    Args:
        log_path (str): path of input file
        
    Returns
        df : pandas dataframe
    """
    pair_list = []
    count = 0
    number_of_threads = 10
    list_job_run_df = []
    
    with open(log_path, 'r') as f:
        Lines = f.readlines()
    
    for line in Lines:
        line_json = json.loads(line)
        if "pair" in line_json:
            pair_list.append(line_json)
        else:
            count += 1
            pair_list.append(line_json)
            if count == 20:
                # covert line_json to df
                job_run_df = pd.DataFrame.from_records(pair_list)
                # add df to list_of_job_df
                list_job_run_df.append(job_run_df)
                # clear pair_list for next run
                pair_list = []
                count = 0
                
    # previous version df_pair_list
    # return len(list_job_run_df)
    return list_job_run_df


def calculate_thread_runtime(df_pair_list):
    """
    Calculates the runtime for thread grouped by MetacacheTread number
    
    Args:
        df_pairs_list (Dataframe) - df_pairs_list per run
        
    Returns
        df :  dataframe with original columns with calculated run_times
    """
    
    list_of_df = []

    for i in range(10):
        thread = f'MetacacheThread-{i}'
        a = df_pair_list[df_pair_list['thread']== thread]
        a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
        a['run_time']=a['timestamp'].diff()
        a.loc[:, 'run_time'] = a.run_time.shift(-1)
        list_of_df.append(a)

    big_df = pd.concat(list_of_df)

    return big_df


def process_each_job(list_job_run_df):
    """
    iterates through list_job_run_df 
    - calculates runtime
    - adds column for run number

    Args:
        list_job_run_df (list(dataframes))

    Return
        dataframe with additional column denoting run number    
    """
    list_processed_df = []
    # iterate thru list_job_run_df
    for i in range(len(list_job_run_df)):
        # run calculate_thread_runtime(df)
        list_of_df = calculate_thread_runtime(list_job_run_df[i])
        # add column to df['run_number'] = i
        list_of_df['run_number'] = i
        list_processed_df.append(list_of_df)
    # combine all df
    all_df = pd.concat(list_processed_df)

    return all_df

# %%
list_job_run_df = read_log('input/metadata_update-extension.log')

# %%
# testing this!
all_df = process_each_job(list_job_run_df)
# Out:
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# ...
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:62: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['timestamp'] = pd.to_datetime(a['timestamp'], infer_datetime_format=True)
# /tmp/ipykernel_4625/187249974.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['run_time']=a['timestamp'].diff()
# /tmp/ipykernel_4625/187249974.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)
# /tmp/ipykernel_4625/187249974.py:64: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   a.loc[:, 'run_time'] = a.run_time.shift(-1)

# %%
# testing this!
print(all_df[all_df['run_number']==2].head(20))
# Out:
#                                event                  logger level  \
# 5   no jobs left, thread terminating  compute_covidcast_meta  info
# 13                   starting thread  compute_covidcast_meta  info
# 19                     starting pair  compute_covidcast_meta  info
# 4   no jobs left, thread terminating  compute_covidcast_meta  info
# 14                   starting thread  compute_covidcast_meta  info
# 15                   starting thread  compute_covidcast_meta  info
# 21                     starting pair  compute_covidcast_meta  info
# 1   no jobs left, thread terminating  compute_covidcast_meta  info
# 16                   starting thread  compute_covidcast_meta  info
# 20                     starting pair  compute_covidcast_meta  info
# 6   no jobs left, thread terminating  compute_covidcast_meta  info
# 17                   starting thread  compute_covidcast_meta  info
# 18                   starting thread  compute_covidcast_meta  info
# 22                   starting thread  compute_covidcast_meta  info
# 3   no jobs left, thread terminating  compute_covidcast_meta  info
# 0   no jobs left, thread terminating  compute_covidcast_meta  info
# 2   no jobs left, thread terminating  compute_covidcast_meta  info
#
#                            timestamp             thread  \
# 5   2022-01-02 08:09:25.739232+00:00  MetacacheThread-0
# 13  2022-01-03 04:00:39.736966+00:00  MetacacheThread-0
# 19  2022-01-03 04:00:39.740320+00:00  MetacacheThread-0
# 4   2022-01-02 04:21:52.788069+00:00  MetacacheThread-1
# 14  2022-01-03 04:00:39.737508+00:00  MetacacheThread-1
# 15  2022-01-03 04:00:39.737944+00:00  MetacacheThread-2
# 21  2022-01-03 04:00:39.742558+00:00  MetacacheThread-2
# 1   2022-01-02 04:21:44.808917+00:00  MetacacheThread-3
# 16  2022-01-03 04:00:39.738266+00:00  MetacacheThread-3
# 20  2022-01-03 04:00:39.741169+00:00  MetacacheThread-3
# 6   2022-01-02 08:09:25.763747+00:00  MetacacheThread-4
# 17  2022-01-03 04:00:39.739166+00:00  MetacacheThread-4
# 18  2022-01-03 04:00:39.739647+00:00  MetacacheThread-5
# 22  2022-01-03 04:00:39.742750+00:00  MetacacheThread-6
# 3   2022-01-02 04:21:52.416680+00:00  MetacacheThread-7
# 0   2022-01-02 04:21:30.903326+00:00  MetacacheThread-8
# 2   2022-01-02 04:21:50.566908+00:00  MetacacheThread-9
#
#                                      pair               run_time  run_number  \
# 5                                     NaN 0 days 19:51:13.997734           2
# 13                                    NaN 0 days 00:00:00.003354           2
# 19    (chng, smoothed_adj_outpatient_cli)                    NaT           2
# 4                                     NaN 0 days 23:38:46.949439           2
# 14                                    NaN                    NaT           2
# 15                                    NaN 0 days 00:00:00.004614           2
# 21    (chng, smoothed_adj_outpatient_flu)                    NaT           2
# 1                                     NaN 0 days 23:38:54.929349           2
# 16                                    NaN 0 days 00:00:00.002903           2
# 20  (chng, smoothed_adj_outpatient_covid)                    NaT           2
# 6                                     NaN 0 days 19:51:13.975419           2
# 17                                    NaN                    NaT           2
# 18                                    NaN                    NaT           2
# 22                                    NaN                    NaT           2
# 3                                     NaN                    NaT           2
# 0                                     NaN                    NaT           2
# 2                                     NaN                    NaT           2
#
#     metadata_calculation_interval_in_seconds  \
# 5                                        NaN
# 13                                       NaN
# 19                                       NaN
# 4                                        NaN
# 14                                       NaN
# 15                                       NaN
# 21                                       NaN
# 1                                        NaN
# 16                                       NaN
# 20                                       NaN
# 6                                        NaN
# 17                                       NaN
# 18                                       NaN
# 22                                       NaN
# 3                                        NaN
# 0                                        NaN
# 2                                        NaN
#
#     metadata_update_interval_in_seconds  total_runtime_in_seconds
# 5                                   NaN                       NaN
# 13                                  NaN                       NaN
# 19                                  NaN                       NaN
# 4                                   NaN                       NaN
# 14                                  NaN                       NaN
# 15                                  NaN                       NaN
# 21                                  NaN                       NaN
# 1                                   NaN                       NaN
# 16                                  NaN                       NaN
# 20                                  NaN                       NaN
# 6                                   NaN                       NaN
# 17                                  NaN                       NaN
# 18                                  NaN                       NaN
# 22                                  NaN                       NaN
# 3                                   NaN                       NaN
# 0                                   NaN                       NaN
# 2                                   NaN                       NaN

# %%
all_df
# Out:
#                                 event                  logger level  \
# 1                     starting thread  compute_covidcast_meta  info
# 9                       starting pair  compute_covidcast_meta  info
# 388                     starting pair  compute_covidcast_meta  info
# 389                     starting pair  compute_covidcast_meta  info
# 397                     starting pair  compute_covidcast_meta  info
# ..                                ...                     ...   ...
# 447                     starting pair  compute_covidcast_meta  info
# 453                     starting pair  compute_covidcast_meta  info
# 460                     starting pair  compute_covidcast_meta  info
# 466                     starting pair  compute_covidcast_meta  info
# 475  no jobs left, thread terminating  compute_covidcast_meta  info
#
#                             timestamp             thread  \
# 1    2022-01-01 04:00:37.116891+00:00  MetacacheThread-0
# 9    2022-01-01 04:00:37.121028+00:00  MetacacheThread-0
# 388  2022-01-01 04:11:01.872179+00:00  MetacacheThread-0
# 389  2022-01-01 04:11:05.806919+00:00  MetacacheThread-0
# 397  2022-01-01 04:13:25.420010+00:00  MetacacheThread-0
# ..                                ...                ...
# 447  2022-01-31 04:52:22.577096+00:00  MetacacheThread-9
# 453  2022-01-31 04:54:11.138902+00:00  MetacacheThread-9
# 460  2022-01-31 04:55:02.544745+00:00  MetacacheThread-9
# 466  2022-01-31 04:55:41.451168+00:00  MetacacheThread-9
# 475  2022-01-31 04:56:28.181931+00:00  MetacacheThread-9
#
#                                              pair               run_time  \
# 1                                             NaN 0 days 00:00:00.004137
# 9           (chng, smoothed_adj_outpatient_covid) 0 days 00:10:24.751151
# 388  (indicator-combination, nmf_day_doc_fbs_ght) 0 days 00:00:03.934740
# 389     (jhu-csse, confirmed_7dav_cumulative_num) 0 days 00:02:19.613091
# 397        (jhu-csse, deaths_7dav_cumulative_num) 0 days 00:02:19.707665
# ..                                            ...                    ...
# 447      (safegraph, median_home_dwell_time_7dav) 0 days 00:01:48.561806
# 453   (usa-facts, confirmed_7dav_cumulative_prop) 0 days 00:00:51.405843
# 460       (usa-facts, deaths_7dav_cumulative_num) 0 days 00:00:38.906423
# 466             (usa-facts, deaths_incidence_num) 0 days 00:00:46.730763
# 475                                           NaN                    NaT
#
#      run_number  metadata_calculation_interval_in_seconds  \
# 1             0                                       NaN
# 9             0                                       NaN
# 388           0                                       NaN
# 389           0                                       NaN
# 397           0                                       NaN
# ..          ...                                       ...
# 447          39                                       NaN
# 453          39                                       NaN
# 460          39                                       NaN
# 466          39                                       NaN
# 475          39                                       NaN
#
#      metadata_update_interval_in_seconds  total_runtime_in_seconds
# 1                                    NaN                       NaN
# 9                                    NaN                       NaN
# 388                                  NaN                       NaN
# 389                                  NaN                       NaN
# 397                                  NaN                       NaN
# ..                                   ...                       ...
# 447                                  NaN                       NaN
# 453                                  NaN                       NaN
# 460                                  NaN                       NaN
# 466                                  NaN                       NaN
# 475                                  NaN                       NaN
#
# [14462 rows x 11 columns]
